# %%
import pandas as pd

df = pd.read_csv ("data/twitter_with_time.csv")

# %%
print(df)
# Out:
#      _id.month  _id.day  _id.year  _id.hour   count
# 0           11        3      2020        19  154277
# 1           10       29      2020        16     261
# 2           10       29      2020        15     338
# 3           10       29      2020         0     245
# 4           10       28      2020        21     292
# ..         ...      ...       ...       ...     ...
# 268         11       20      2020         4  167788
# 269         10       30      2020         8  131833
# 270         11       21      2020         5  142776
# 271         11        5      2020         4   62724
# 272         11       21      2020         6   67978
#
# [273 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
x = df['_id.day']
y = df['count']

# %%
from pandas import read_csv
from matplotlib import pyplot

# %%
xvalues=[]
yvalues=[]
hvalues=[]
for i, j in df.iterrows(): 
    #print(i, j) 
   # yvalues.append(df[i][j])
    #print(j["_id.year"].apply(str)+""+j["_id.month"].apply(str)+""+j["_id.day"].apply(str)+""+j["_id.hour"].apply(str))  
   # print(str(j["_id.year"])+str(j["_id.month"])+str(j["_id.day"])+str(j["_id.hour"]))
  # df["Day"].astype(str).str.zfill(2) + "-" + df["Hour"].astype(str).str.zfill(2)
   # print(str(j["_id.year"])+str(j["_id.month"]).zfill(2)+str(j["_id.day"]).zfill(2)+str(j["_id.hour"]).zfill(2))
    xvalues.append(str(j["_id.year"])+str(j["_id.month"]).zfill(2)+str(j["_id.day"]).zfill(2)+str(j["_id.hour"]).zfill(2))  
    yvalues.append (j["count"])

# %%
plt.title('Twitter data collected from 11th November 2020 through 22nd November 2020',fontsize=7)
plt.xlabel("Days from 11th November 2020 through 22nd November 2020",fontsize=7)
plt.ylabel("Data Collected",fontsize=7)
ax.xaxis.set_major_locator(mticker.MultipleLocator(23))
plt.tight_layout()
plt.bar(xvalues,yvalues)     
ax = plt.gca()

#ax.axes.xaxis.set_visible(False)
# labels = ['1','','','','','','','','','','','','','','','','','','','','','','','','','','','','','','','']
# ax.set_xticks(np.arange(len(labels)))
# ax.set_xticklabels(labels)
#plt.xlim(0, 10)

plt.xticks(rotation=90,fontsize=7)
plt.yticks(rotation=90,fontsize=7)
ax.xaxis.set_major_locator(mticker.MultipleLocator(23))
plt.savefig("test.png",bbox_inches='tight')
# # ax.xaxis.set_minor_locator(mticker.MultipleLocator(1))
# ax.xaxis.set_minor_formatter(mticker.NullFormatter())
plt.tight_layout()
